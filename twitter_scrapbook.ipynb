# %%
import os
from TwitterAPI import TwitterAPI


CONSUMER_KEY = os.environ['CONSUMER_KEY']
CONSUMER_SECRET = os.environ['CONSUMER_SECRET']
OAUTH_TOKEN = os.environ['OAUTH_TOKEN']
OAUTH_SECRET = os.environ['OAUTH_SECRET']

api = TwitterAPI(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_SECRET)

# %%
# trinity = api.request('search/tweets', {'q': 'trinity', 'count': 100,
#                                         'since':'2015-10-16' })

# %%
trinity = api.request('search/tweets', {'q': 'trinity', 'count': 100,
                                        'since':'2015-10-09' })

# %%
[i for i in trinity]
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Oct 12 13:11:35 +0000 2015',
#   'entities': {'hashtags': [{'indices': [102, 129],
#      'text': 'EMABiggestFansJustinBieber'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 653558634719367169,
#   'id_str': '653558634719367169',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'pl',
#   'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
# ...

# %%
[print(i['text'], i['favorite_count'], i['created_at']) for i in trinity]
# Out:
# [He was] a solemn, unsmiling, sanctimonious old iceberg who looked like he was waiting for a vacancy in the Trinity. ― Mark Twain 0 Tue Oct 20 20:23:27 +0000 2015
# #trinitybellwoods @ Trinity Bellwoods Park https://t.co/G5WxHo8de3 0 Tue Oct 20 20:23:26 +0000 2015
# @TomHartleySnr Wow TH have you bought The Holy Trinity in one day ?? LaF, P1 and 918 #whatafirm 0 Tue Oct 20 20:23:19 +0000 2015
# RT @sonsomething: Seulgi &gt;&gt; wendy &gt;&gt; irene &gt;&gt; fans
#
# RIP holy trinity pairings https://t.co/eByAox36z2 0 Tue Oct 20 20:23:08 +0000 2015
# #20DaysUntilTheOutfield    https://t.co/LMrEVeLnXY 0 Tue Oct 20 20:23:08 +0000 2015
# RT @ArchbishopGomez: This is God’s plan for the human #family. Every family is called to be a “domestic church” reflecting the communion of… 0 Tue Oct 20 20:23:07 +0000 2015
# . @shalouisville and @GoRocks take part in lacrosse benefit match https://t.co/5t6otMDKt9 0 Tue Oct 20 20:22:42 +0000 2015
# ...

# %%
type(response)
# Out:
# TwitterAPI.TwitterAPI.TwitterResponse
